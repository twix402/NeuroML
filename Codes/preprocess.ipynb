# %%
import numpy as np
import pandas as pd

# %%
path = '../Datasets/EEG_data.csv'
input= pd.read_csv(path)
input.info()
input
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Columns: 1149 entries, no. to COH.F.gamma.r.O1.s.O2
# dtypes: float64(1144), int64(1), object(4)
# memory usage: 8.3+ MB
#      no. sex   age    eeg.date  education     IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30        NaN    NaN  Addictive disorder
# 1      2   M  37.0    2012.9.6        6.0  120.0  Addictive disorder
# 2      3   M  32.0   2012.9.10       16.0  113.0  Addictive disorder
# 3      4   M  35.0   2012.10.8       18.0  126.0  Addictive disorder
# 4      5   M  36.0  2012.10.18       16.0  112.0  Addictive disorder
# ..   ...  ..   ...         ...        ...    ...                 ...
# 940  941   M  22.0   2014.8.28       13.0  116.0     Healthy control
# 941  942   M  26.0   2014.9.19       13.0  118.0     Healthy control
# 942  943   M  26.0   2014.9.27       16.0  113.0     Healthy control
# 943  944   M  24.0   2014.9.20       13.0  107.0     Healthy control
# ...

# %%
ptsd = input[input['specific.disorder'] == 'Posttraumatic stress disorder']
hc = input[input['specific.disorder'] == 'Healthy control'].sample(n=52, random_state=42)
data = pd.concat([ptsd, hc])
data
# Out:
#      no. sex    age   eeg.date  education     IQ  \
# 297  298   F  36.62  2011.1.28       12.0   99.0
# 309  310   F  55.21   2012.4.9       16.0  120.0
# 310  311   F  26.93  2011.3.24       16.0  116.0
# 315  316   M  26.71   2012.7.3       17.0  137.0
# 318  319   F  23.45   2014.6.2       12.0   89.0
# ..   ...  ..    ...        ...        ...    ...
# 137  138   F  29.04   2018.8.9       16.0  114.0
# 116  117   F  25.65   2018.7.2       18.0  118.0
# 130  131   F  29.86  2018.7.19       20.0  113.0
# 184  185   M  27.00  2017.4.29       18.0  130.0
# 121  122   F  23.66   2018.7.6       17.0  130.0
#
#                           main.disorder              specific.disorder  \
# 297  Trauma and stress related disorder  Posttraumatic stress disorder
# 309  Trauma and stress related disorder  Posttraumatic stress disorder
# 310  Trauma and stress related disorder  Posttraumatic stress disorder
# 315  Trauma and stress related disorder  Posttraumatic stress disorder
# ...

# %%
data.drop('no.', axis=1, inplace=True)
data.drop('eeg.date', axis=1, inplace=True)
data.drop('main.disorder', axis=1, inplace=True)
data.drop('age', axis=1, inplace=True)
data.drop('sex', axis=1, inplace=True)
data.drop('education', axis=1, inplace=True)

data.reset_index(drop=True, inplace=True)
data.drop('index', axis=1, errors='ignore')
data.index = range(1, len(data) + 1)
data
# Out:
#         IQ              specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 1     99.0  Posttraumatic stress disorder         17.603385         17.243334
# 2    120.0  Posttraumatic stress disorder         21.714048         19.579805
# 3    116.0  Posttraumatic stress disorder         13.371076         14.028142
# 4    137.0  Posttraumatic stress disorder         30.473244         13.954586
# 5     89.0  Posttraumatic stress disorder         18.488575         19.603144
# ..     ...                            ...               ...               ...
# 100  114.0                Healthy control         22.737005         23.110192
# 101  118.0                Healthy control         20.081892         17.928614
# 102  113.0                Healthy control         46.306229         47.379694
# 103  130.0                Healthy control         22.152399         22.698280
# 104  130.0                Healthy control         37.450821         54.405099
#
# ...

# %%
data.to_csv('../Datasets/PTSD_data.csv')

# %%
data['specific.disorder'] = data['specific.disorder'].map({'Posttraumatic stress disorder': 1, 'Healthy control': 0})

# %%
separator = data.columns.get_loc(data.columns[data.isnull().all()][0])
AB_data = data.iloc[:,:separator]
COH_data = data.iloc[:, list(range(5)) + list(range(separator+1 , data.shape[1]))]

# %%
data=data.drop(columns='Unnamed: 122')
data
# Out:
#         IQ  specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 1     99.0                  1         17.603385         17.243334
# 2    120.0                  1         21.714048         19.579805
# 3    116.0                  1         13.371076         14.028142
# 4    137.0                  1         30.473244         13.954586
# 5     89.0                  1         18.488575         19.603144
# ..     ...                ...               ...               ...
# 100  114.0                  0         22.737005         23.110192
# 101  118.0                  0         20.081892         17.928614
# 102  113.0                  0         46.306229         47.379694
# 103  130.0                  0         22.152399         22.698280
# 104  130.0                  0         37.450821         54.405099
#
#      AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  \
# 1          11.729942        15.381709        18.307108        28.369365
# ...

# %%
data.to_csv('../Datasets/PTSD_data_mapped.csv')
AB_data.to_csv('../Datasets/AB_data.csv')
COH_data.to_csv('../Datasets/COH_data.csv')
