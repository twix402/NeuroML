# %% [markdown]
# <h1 style="
# font-weight: bold; ">Mapping and Visualizing EEG Data</h1>

# %% [markdown]
# <h2  style="color:#FF6347; font-weight:bold">Notebook Overview:</h2>

# %% [markdown]
# This notebook provides a comprehensive guide to mapping and visualizing EEG (electroncephalogram) electrode positions using Python, with a focus on the MNE library.
#
# <h3 style="color:#FF6347;  font-weight:bold">It covers:</h3>
#
# - Installation and import of essential libraries for EEG data analysis.
# - Defining and mapping 2D coordinates of EEG electrodes based on the 10-20 system.
# - Visualizing electrode positions to aid in understanding spatial layouts.

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mne #the `mne` library, which is essential for EEG/MEG data processing and visualization. 
import math

# %% [markdown]
# <h2 style="color:#FF6347; font-weight: bold; ">Expanding Electrode Positions to 3D Coordinates :-</h3>
#
# - This dictionary (`chs`) specifies the 2D coordinates of EEG electrodes based on the 10-20 system, which is commonly used in EEG data analysis.
# - Each key is the electrode name (e.g., 'FP1', 'Fz'), and each value is a list containing the x and y coordinates for that electrode. These coordinates will be used later to visualize electrode positions on a 2D plane.

# %%
# Dictionary defining EEG electrode positions using the 10-20 system
# Keys are electrode names; values are [x, y] coordinates
chs = {
    'FP1': [-0.03, 0.08],
    'FP2': [0.03, 0.08],
    'F7': [-0.073, 0.047],
    'F3': [-0.04, 0.041],
    'Fz': [0, 0.038],
    'F4': [0.04, 0.041],
    'F8': [0.073, 0.047],
    'T3': [-0.085, 0],
    'C3': [-0.045, 0],
    'Cz': [0, 0],
    'C4': [0.045, 0],
    'T4': [0.085, 0],
    'T5': [-0.073, -0.047],
    'P3': [-0.04, -0.041],
    'Pz': [0, -0.038],
    'P4': [0.04, -0.041],
    'T6': [0.07, -0.047],
    'O1': [-0.03, -0.08],
    'O2': [0.03, -0.08]
}

# %%
# Convert the electrode position dictionary to a DataFrame and transpose
# Electrode names become row indices, and x, y coordinates are columns
channels = pd.DataFrame(chs).transpose()
channels  # Display the DataFrame of electrode positions
# Out:
#          0      1
# FP1 -0.030  0.080
# FP2  0.030  0.080
# F7  -0.073  0.047
# F3  -0.040  0.041
# Fz   0.000  0.038
# F4   0.040  0.041
# F8   0.073  0.047
# T3  -0.085  0.000
# C3  -0.045  0.000
# Cz   0.000  0.000
# C4   0.045  0.000
# T4   0.085  0.000
# T5  -0.073 -0.047
# P3  -0.040 -0.041
# Pz   0.000 -0.038
# P4   0.040 -0.041
# T6   0.070 -0.047
# O1  -0.030 -0.080
# O2   0.030 -0.080

# %% [markdown]
# <h3 style="color:#FF6347; font-weight: bold;">Expanding Electrode Positions to 3D Coordinates :-</h3>

# %%
# Expand each electrode position to 3D by adding a z-coordinate of 0
for key in chs.keys():
    chs[key] += [0]  # Append 0 as the z-coordinate
chs  # Display updated dictionary with 3D coordinates
# Out:
# {'FP1': [-0.03, 0.08, 0],
#  'FP2': [0.03, 0.08, 0],
#  'F7': [-0.073, 0.047, 0],
#  'F3': [-0.04, 0.041, 0],
#  'Fz': [0, 0.038, 0],
#  'F4': [0.04, 0.041, 0],
#  'F8': [0.073, 0.047, 0],
#  'T3': [-0.085, 0, 0],
#  'C3': [-0.045, 0, 0],
#  'Cz': [0, 0, 0],
#  'C4': [0.045, 0, 0],
#  'T4': [0.085, 0, 0],
#  'T5': [-0.073, -0.047, 0],
#  'P3': [-0.04, -0.041, 0],
#  'Pz': [0, -0.038, 0],
#  'P4': [0.04, -0.041, 0],
#  'T6': [0.07, -0.047, 0],
#  'O1': [-0.03, -0.08, 0],
#  'O2': [0.03, -0.08, 0]}

# %% [markdown]
# <h3 style="color:#FF6347;font-weight: bold;">Creating and Plotting EEG Electrode Montage :-</h3>
#
# - We use MNE's `make_dig_montage` function to create a montage from the 3D electrode positions defined in `chs`.
# - A montage aligns and organizes electrode positions, allowing for accurate visualization and further EEG data analysis.
# - We then plot the montage to visualize the electrode layout.

# %%
# Import necessary library
import matplotlib.pyplot as plt

# Create a digital montage from the 3D electrode positions
mont = mne.channels.make_dig_montage(chs)

# Plot the montage with color customization
fig = mont.plot(show=False)  # Set show=False to modify the figure before displaying

# Customize the plot using matplotlib
for ax in fig.get_axes():
    # Change the color of electrode points and labels
    for line in ax.get_lines():
        line.set_color('red')  # Change 'red' to your preferred color

plt.suptitle('EEG Electrode Layout', fontsize=16, color='black')  # Add a title for context
plt.show()
# Out:
# /var/folders/g9/s_fx5qk126515rbzxjm9x6ww0000gn/T/ipykernel_72718/3894566217.py:8: RuntimeWarning: Fiducial point nasion not found, assuming identity unknown to head transformation
#   fig = mont.plot(show=False)  # Set show=False to modify the figure before displaying

# %% [markdown]
# <h3 style="color:#FF6347;font-weight: bold;">Loading EEG Dataset :-</h3>

# %%
df = pd.read_csv('../Datasets/EEG_data.csv')
df
# Out:
#      no. sex   age    eeg.date  education     IQ       main.disorder  \
# 0      1   M  57.0   2012.8.30        NaN    NaN  Addictive disorder
# 1      2   M  37.0    2012.9.6        6.0  120.0  Addictive disorder
# 2      3   M  32.0   2012.9.10       16.0  113.0  Addictive disorder
# 3      4   M  35.0   2012.10.8       18.0  126.0  Addictive disorder
# 4      5   M  36.0  2012.10.18       16.0  112.0  Addictive disorder
# ..   ...  ..   ...         ...        ...    ...                 ...
# 940  941   M  22.0   2014.8.28       13.0  116.0     Healthy control
# 941  942   M  26.0   2014.9.19       13.0  118.0     Healthy control
# 942  943   M  26.0   2014.9.27       16.0  113.0     Healthy control
# 943  944   M  24.0   2014.9.20       13.0  107.0     Healthy control
# 944  945   M  21.0  2015.10.23       13.0  105.0     Healthy control
#
#         specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0    Alcohol use disorder         35.998557         21.717375  ...
# 1    Alcohol use disorder         13.425118         11.002916  ...
# 2    Alcohol use disorder         29.941780         27.544684  ...
# 3    Alcohol use disorder         21.496226         21.846832  ...
# 4    Alcohol use disorder         37.775667         33.607679  ...
# ..                    ...               ...               ...  ...
# 940       Healthy control         41.851823         36.771496  ...
# 941       Healthy control         18.986856         19.401387  ...
# 942       Healthy control         28.781317         32.369230  ...
# 943       Healthy control         19.929100         25.196375  ...
# 944       Healthy control         65.195346         69.241972  ...
#
#      COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0                55.989192              16.739679              23.452271
# 1                45.595619              17.510824              26.777368
# 2                99.475453              70.654171              39.131547
# 3                59.986561              63.822201              36.478254
# 4                61.462720              59.166097              51.465531
# ..                     ...                    ...                    ...
# 940              82.905657              34.850706              63.970519
# 941              65.917918              66.700117              44.756285
# 942              61.040959              27.632209              45.552852
# 943              99.113664              48.328934              41.248470
# 944              78.600293              68.255430              70.687410
#
#      COH.F.gamma.o.Pz.s.O2  COH.F.gamma.p.P4.q.T6  COH.F.gamma.p.P4.r.O1  \
# 0                45.678820              30.167520              16.918761
# 1                28.201062              57.108861              32.375401
# 2                69.920996              71.063644              38.534505
# 3                47.117006              84.658376              24.724096
# 4                58.635415              80.685608              62.138436
# ..                     ...                    ...                    ...
# 940              63.982003              51.244725              62.203684
# 941              49.787513              98.905995              54.021304
# 942              33.638817              46.690983              19.382928
# 943              28.192238              48.665743              42.007147
# 944              74.433908              74.294750              53.254681
#
#      COH.F.gamma.p.P4.s.O2  COH.F.gamma.q.T6.r.O1  COH.F.gamma.q.T6.s.O2  \
# 0                48.850427               9.422630              34.507082
# 1                60.351749              13.900981              57.831848
# 2                69.908764              27.180532              64.803155
# 3                50.299349              35.319695              79.822944
# 4                75.888749              61.003944              87.455509
# ..                     ...                    ...                    ...
# 940              62.062237              31.013031              31.183413
# 941              93.902401              52.740396              92.807331
# 942              41.050717               7.045821              41.962451
# 943              28.735945              27.176500              27.529522
# 944              72.755265              47.810386              80.166825
#
#      COH.F.gamma.r.O1.s.O2
# 0                28.613029
# 1                43.463261
# 2                31.485799
# 3                41.141873
# 4                70.531662
# ..                     ...
# 940              98.325230
# 941              56.320868
# 942              19.092111
# 943              20.028446
# 944              64.380273
#
# [945 rows x 1149 columns]

# %% [markdown]
# <h3 style="color:#FF6347;font-weight: bold;">Identifying and Removing Empty Columns :-</h3>

# %%
# Calculate the number of missing values in each column
mis = df.isna().sum()

# Identify the first column with all values missing
separator = mis[mis == df.shape[0]].index[0]

# Slice the DataFrame to include only relevant columns, dropping the first empty column
df = df.loc[:, 'main.disorder':separator].drop(separator, axis=1)
df  # Display the cleaned DataFrame


df
# Out:
#           main.disorder     specific.disorder  AB.A.delta.a.FP1  \
# 0    Addictive disorder  Alcohol use disorder         35.998557
# 1    Addictive disorder  Alcohol use disorder         13.425118
# 2    Addictive disorder  Alcohol use disorder         29.941780
# 3    Addictive disorder  Alcohol use disorder         21.496226
# 4    Addictive disorder  Alcohol use disorder         37.775667
# ..                  ...                   ...               ...
# 940     Healthy control       Healthy control         41.851823
# 941     Healthy control       Healthy control         18.986856
# 942     Healthy control       Healthy control         28.781317
# 943     Healthy control       Healthy control         19.929100
# 944     Healthy control       Healthy control         65.195346
#
#      AB.A.delta.b.FP2  AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  \
# 0           21.717375        21.518280        26.825048        26.611516
# 1           11.002916        11.942516        15.272216        14.151570
# 2           27.544684        17.150159        23.608960        27.087811
# 3           21.846832        17.364316        13.833701        14.100954
# 4           33.607679        21.865556        21.771413        22.854536
# ..                ...              ...              ...              ...
# 940         36.771496        43.671792        36.860889        24.732236
# 941         19.401387        27.586436        20.194732        19.407491
# 942         32.369230        11.717778        23.134370        26.209302
# 943         25.196375        14.445391        16.453456        16.590649
# 944         69.241972        35.361363        28.089348        35.475808
#
#      AB.A.delta.f.F4  AB.A.delta.g.F8  AB.A.delta.h.T3  ...  AB.F.gamma.j.Cz  \
# 0          25.732649        16.563408        29.891368  ...         1.993727
# 1          12.456034         8.436832         9.975238  ...         0.903383
# 2          13.541237        16.523963        12.775574  ...         1.096713
# 3          13.100939        14.613650         8.063191  ...         1.115040
# 4          21.456377        15.969042         9.434306  ...         1.193191
# ..               ...              ...              ...  ...              ...
# 940        23.607823        23.288260         7.520642  ...         1.966436
# 941        20.216570        16.465027        13.178851  ...         2.701922
# 942        25.484497        22.586688        11.368466  ...         3.258838
# 943        16.007279        18.909188        13.438102  ...         1.849005
# 944        36.804968        69.071230         6.905352  ...         0.622001
#
#      AB.F.gamma.k.C4  AB.F.gamma.l.T4  AB.F.gamma.m.T5  AB.F.gamma.n.P3  \
# 0           1.765493         1.464281         1.501948         1.707307
# 1           0.931967         0.437117         0.930843         1.234874
# 2           1.691152         1.505663         1.133891         1.661768
# 3           1.122776         2.128138         1.648217         1.147666
# 4           2.320845         3.562820         1.441662         1.018804
# ..               ...              ...              ...              ...
# 940         1.763397         1.285942         2.437923         2.130979
# 941         2.685138         2.648595         2.559590         3.054965
# 942         2.434620         1.501337         0.840513         1.733498
# 943         1.678465         3.655796         1.429330         3.151128
# 944         0.972956         2.340291         0.621251         0.750963
#
#      AB.F.gamma.o.Pz  AB.F.gamma.p.P4  AB.F.gamma.q.T6  AB.F.gamma.r.O1  \
# 0           1.553448         1.552658         1.388662         1.592717
# 1           1.373268         1.411808         1.140695         1.118041
# 2           1.403429         1.349457         1.270525         1.408471
# 3           1.049152         1.131654         1.415856         1.391048
# 4           1.274009         2.350806         2.307730         2.129431
# ..               ...              ...              ...              ...
# 940         1.727413         1.710518         2.574734         2.533354
# 941         3.163359         3.247100         2.646515         3.385173
# 942         1.610465         1.644675         1.216763         1.614421
# 943         1.630643         1.888551         1.447402         1.819110
# 944         0.785956         0.785196         1.205448         1.711367
#
#      AB.F.gamma.s.O2
# 0           1.806598
# 1           3.162143
# 2           1.454618
# 3           1.527403
# 4           3.766860
# ..               ...
# 940         5.596057
# 941         3.085049
# 942         1.164097
# 943         1.302056
# 944         5.188920
#
# [945 rows x 116 columns]

# %% [markdown]
# <h3 style="color:#FF6347;font-weight: bold;">Reformatting Column Names :-</h3>

# %%
# Define a function to reformat column names to the format 'band.channel'
def reformat_name(name):
    band, _, channel = name[5:].split(sep='.')
    return f'{band}.{channel}'

# Vectorize the reformat_name function to apply it to an array of column names
reformat_vect = np.vectorize(reformat_name)
new_colnames = np.concatenate((df.columns[:2], reformat_vect(df.columns[2:])))

# Update the DataFrame with the new column names
renamed_df = df.set_axis(new_colnames, axis=1)
renamed_df.columns  # Display the updated column names
# Out:
# Index(['main.disorder', 'specific.disorder', 'delta.FP1', 'delta.FP2',
#        'delta.F7', 'delta.F3', 'delta.Fz', 'delta.F4', 'delta.F8', 'delta.T3',
#        ...
#        'gamma.Cz', 'gamma.C4', 'gamma.T4', 'gamma.T5', 'gamma.P3', 'gamma.Pz',
#        'gamma.P4', 'gamma.T6', 'gamma.O1', 'gamma.O2'],
#       dtype='object', length=116)

# %% [markdown]
# <h3 style="color:#FF6347;font-weight: bold;">Calculating Mean by Disorder and Reshaping Data :-</h3>

# %%
mean = renamed_df.groupby('specific.disorder').mean(numeric_only=True).reset_index()
mean
# Out:
#                  specific.disorder  delta.FP1  delta.FP2   delta.F7  \
# 0            Acute stress disorder  21.010092  21.610872  18.642425
# 1              Adjustment disorder  22.409204  25.012049  19.624888
# 2             Alcohol use disorder  19.031935  18.716010  16.027841
# 3    Behavioral addiction disorder  18.631096  19.062980  15.305196
# 4                 Bipolar disorder  20.920267  21.376145  19.441296
# 5              Depressive disorder  20.561897  22.291184  17.826752
# 6                  Healthy control  18.383673  19.497090  15.526428
# 7   Obsessive compulsitve disorder  18.261254  19.495833  15.907084
# 8                   Panic disorder  18.514396  19.403421  17.889956
# 9    Posttraumatic stress disorder  22.263038  22.424307  18.982890
# 10                   Schizophrenia  21.537751  22.646490  19.992494
# 11         Social anxiety disorder  22.299856  23.958653  20.138141
#
#      delta.F3   delta.Fz   delta.F4   delta.F8   delta.T3   delta.C3  ...  \
# 0   20.605466  22.649437  21.081192  18.043201  13.329125  18.174049  ...
# 1   20.485676  22.977661  21.877866  17.720373  11.994227  17.534495  ...
# 2   17.875001  19.305932  18.750400  15.929314  10.745089  15.473224  ...
# 3   17.757391  20.445102  18.428716  14.997956  10.111161  15.204398  ...
# 4   19.799656  20.603657  19.950937  16.799036  12.930464  17.450318  ...
# 5   19.394730  20.836428  20.137376  17.662349  12.056048  16.672858  ...
# 6   17.398592  18.687952  17.443004  16.333668   9.459207  14.955463  ...
# 7   16.771218  18.489591  17.555625  14.933192  10.845902  14.746984  ...
# 8   17.804156  20.004586  18.699839  17.107922  12.282164  15.975269  ...
# 9   19.906076  21.546656  20.148717  17.807032  13.828257  17.335792  ...
# 10  19.890804  21.009200  20.683710  18.344536  12.783527  17.231452  ...
# 11  20.074442  20.422282  19.761389  18.938161  13.278684  17.649808  ...
#
#     gamma.Cz  gamma.C4  gamma.T4  gamma.T5  gamma.P3  gamma.Pz  gamma.P4  \
# 0   2.222058  2.010888  2.148256  1.853432  2.026037  2.053871  2.033871
# 1   3.033030  2.794749  3.314235  2.027649  2.464426  2.680733  2.665490
# 2   1.950866  1.829302  1.741237  1.554061  1.735008  1.755539  1.788144
# 3   2.917787  2.619295  3.227874  2.177208  2.365449  2.429706  2.430918
# 4   3.258559  3.266933  3.086824  2.412918  2.837179  2.914106  2.873441
# 5   2.926890  3.047236  2.874408  2.339983  2.539246  2.534559  2.557899
# 6   2.450552  2.396678  2.665862  1.758386  2.067072  2.139128  2.173021
# 7   2.773261  2.887474  3.647183  2.077698  2.360582  2.433777  2.492759
# 8   2.433170  2.341830  2.265596  2.032189  2.215160  2.176705  2.170567
# 9   3.224249  3.566281  3.468531  2.477028  2.896576  2.792276  2.870593
# 10  3.080554  3.041254  3.387337  2.435776  2.736861  2.799705  2.865227
# 11  2.702081  2.586318  2.411107  2.001059  2.322667  2.449024  2.571677
#
#     gamma.T6  gamma.O1  gamma.O2
# 0   1.913955  2.841223  2.453071
# 1   2.451450  4.044013  3.803860
# 2   1.669162  2.721851  2.557966
# 3   2.212409  3.642643  3.729947
# 4   3.110626  3.945114  4.178363
# 5   2.522967  3.696353  3.425693
# 6   2.146132  2.702684  2.990976
# 7   2.556206  3.074281  3.304698
# 8   2.098515  3.960791  4.539175
# 9   2.772858  4.559529  3.706658
# 10  2.966232  4.257993  3.868594
# 11  2.575262  2.780403  3.656876
#
# [12 rows x 115 columns]

# %%
bands = ['delta', 'theta', 'alpha', 'beta', 'highbeta', 'gamma']
mean = pd.wide_to_long(mean, stubnames=bands, i='specific.disorder', j='channel', sep='.', suffix=r'\w+')
mean
# Out:
#                                             delta      theta      alpha  \
# specific.disorder              channel
# Acute stress disorder          FP1      21.010092  21.449696  29.986463
# Adjustment disorder            FP1      22.409204  15.188234  27.723441
# Alcohol use disorder           FP1      19.031935  14.487469  31.710026
# Behavioral addiction disorder  FP1      18.631096  13.186498  16.906313
# Bipolar disorder               FP1      20.920267  12.899219  22.731308
# ...                                           ...        ...        ...
# Obsessive compulsitve disorder O2       11.490165   9.438324  31.925618
# Panic disorder                 O2       13.623837   8.332327  20.802839
# Posttraumatic stress disorder  O2       13.845669  10.241304  28.496422
# Schizophrenia                  O2       14.780898   9.635807  28.995409
# Social anxiety disorder        O2       15.762618  10.008300  31.698667
#
#                                              beta  highbeta     gamma
# specific.disorder              channel
# Acute stress disorder          FP1      14.860550  2.419641  2.379800
# Adjustment disorder            FP1      11.964587  2.481214  3.110645
# Alcohol use disorder           FP1      12.026554  2.016023  2.193860
# Behavioral addiction disorder  FP1       9.149485  2.067112  2.643175
# Bipolar disorder               FP1      13.258815  2.519366  3.336706
# ...                                           ...       ...       ...
# Obsessive compulsitve disorder O2       11.461414  2.151135  3.304698
# Panic disorder                 O2       12.606385  2.855598  4.539175
# Posttraumatic stress disorder  O2       14.237963  2.411561  3.706658
# Schizophrenia                  O2       14.521340  2.627968  3.868594
# Social anxiety disorder        O2       15.721296  2.463267  3.656876
#
# [228 rows x 6 columns]

# %% [markdown]
# <h3 style="color:#FF6347; font-weight: bold; ">Plotting EEG Data on a Topomap :-</h3>
#
# - The `plot_eeg` function visualizes EEG data on a topographical map:
# -  `levels` represents the EEG data values (e.g., voltage) at each electrode.
# - `positions` specifies the (x, y) positions of the electrodes.
# - The function uses `mne.viz.plot_topomap` to create the plot and adds a colorbar to the figure for better interpretation of values.
# - Optional parameters allow customization of the plot appearance, including color maps, colorbar size, and masking of specific values.

# %%
def plot_eeg(levels, positions, axes, fig, ch_names=None, cmap=None, cb_pos=(0.9, 0.1), vmin=None, vmax=None,
             cb_width=0.04, cb_height=0.9, marker=None, marker_style=None, **kwargs):
    # If no mask is specified in kwargs, create a mask array of ones (i.e., no masking)
    if 'mask' not in kwargs:
        mask = np.ones(levels.shape[0], dtype='bool')
    else:
        mask = None  # If a mask is provided in kwargs, use it directly

    # Plot the topographical map using MNE's `plot_topomap` function
    im, cm = mne.viz.plot_topomap(levels, positions, axes=axes, names=ch_names,
                                   cmap=cmap, mask=mask, mask_params=marker_style, vlim=(vmin, vmax), show=False, **kwargs)

    # Add a colorbar to the figure for visualizing the data range
    cbar_ax = fig.add_axes([cb_pos[0], cb_pos[1], cb_width, cb_height])  # Position and size of colorbar
    clb = axes.figure.colorbar(im, cax=cbar_ax)  # Associate the colorbar with the topomap image

    return im, cm  # Return the image and color map objects for further manipulation or saving

# %% [markdown]
# <h3 style="color:#FF6347;font-weight: bold;">Plotting EEG Dataset</h3>
#
# - The `plot_eeg_dataset` function visualizes EEG data across multiple conditions and frequency bands. It arranges the topographic maps into a grid of subplots:
# - **Bands and Conditions**: Each row corresponds to a specific EEG band, and each column represents a specific condition (disorder).
# - **Customizability**: The function supports customization of figure dimensions, labels for bands and conditions, and the appearance of the plots (e.g., colormap, marker style).
# - **Annotations**: The plots are annotated with the band and condition labels to ensure clarity in interpretation.

# %%
def plot_eeg_dataset(dataset, channels, gwidth=2, gheight=1.5, wspace=0,
                     marker_style={'markersize': 2, 'markerfacecolor': 'black'},
                     band_ordered=None, conditions_ordered=None, band_labels=None,
                     condition_labels=None, cmap=None, **kwargs):
    """
    Function to plot EEG data as topographical maps for each condition and frequency band.

    Parameters:
    - dataset (DataFrame): The EEG data in a long format.
    - channels (DataFrame): Electrode position information.
    - gwidth, gheight (float): Size of each subplot.
    - wspace (float): The width space between subplots.
    - marker_style (dict): M++ arker style for the electrodes on the topomap.
    - band_ordered (list): The frequency bands to plot.
    - conditions_ordered (list): The conditions or disorders to plot.
    - band_labels (list): Labels for the frequency bands.
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
 
    - condition_labels (list): Labels for the conditions or disorders.
    - cmap (str): Color map for the topomap.
    - kwargs: Additional arguments for customization.

    Returns:
    - fig (Figure): The created figure.
    - subfigs (Subfigure): The subfigures for each plot.
    """
    # Default to dataset columns for bands and rows for conditions if not provided
    if band_ordered is None:
        band_ordered = dataset.columns
    if conditions_ordered is None:
        conditions_ordered = dataset.index.get_level_values(0).unique()
    if band_labels is None:
        band_labels = band_ordered
    if condition_labels is None:
        condition_labels = conditions_ordered

    # Determine the number of rows and columns for the figure
    nrows = len(band_ordered)
    ncols = len(conditions_ordered)

    # Create figure with appropriate size based on number of subplots
    fig = plt.figure(constrained_layout=True, figsize=(gwidth*ncols, gheight*nrows))
    subfigs = fig.subfigures(nrows, ncols, wspace=wspace)  # Create subfigures for each combination

    # Loop through subfigures to plot the EEG data for each band-condition combination
    for ind, subfig in np.ndenumerate(subfigs):
        i, j = ind
        band = band_ordered[i]  # Select the current band
        disorder = conditions_ordered[j]  # Select the current disorder/condition
        levels = dataset.loc[disorder, band]  # Get EEG data for the current band-condition pair

        ax = subfig.subplots()  # Create a subplot for this combination
        vmin = 0  # Minimum color value for the plot
        vmax = math.ceil(max(dataset[band]))  # Maximum color value based on the dataset's max for the band

        # Call the `plot_eeg` function to plot the topomap
        plot_eeg(levels, channels.to_numpy(), ax, subfig, marker_style=marker_style, cmap=cmap, vmin=vmin, vmax=vmax, **kwargs)

        # Annotate the band label (leftmost column)
        if j == 0:
            ax.set_ylabel(band_labels[i])

        # Annotate the disorder condition label (top row)
        if i == 0:
            subfig.suptitle(condition_labels[j], y=1.3)

    return fig, subfigs  # Return the figure and subfigures for further manipulation or saving

# %% [markdown]
# <h3 style="color:#FF6347;font-weight: bold;">Plotting EEG Topographic Maps for Conditions</h3>
#
# - We define the conditions (disorders) we are interested in and order them for visualization.
# - The `plot_topomap` function is then called to visualize EEG data across these conditions, using the `coolwarm` colormap.
# - The function arranges the plots in a grid, where each plot represents EEG data for a particular band and disorder.
# - The resulting plots are displayed for easy interpretation of the data.

# %%
def plot_topomap(data, positions, ax, cmap='viridis_r', vmin=None, vmax=None):
    """
    Plot a topomap with a colorbar using MNE's plot_topomap and add a box around the image and colorbar.

    Parameters:
    - data (array-like): EEG values to plot.
    - positions (array-like): Electrode positions in 2D.
    - ax (Axes): Axis to draw the plot.
    - cmap (str): Colormap for visualization (inverted by default).
    - vmin, vmax (float): Minimum and maximum values for the colorbar.
    """
    sphere = (0, 0, 0, 0.09)  # Defines head dimensions for visualization
    im, _ = mne.viz.plot_topomap(
        data, positions, axes=ax, cmap=cmap, vlim=(vmin, vmax), sphere=sphere, show=False
    )
    ax.set_xticks([])
    ax.set_yticks([])

    # Adding a colorbar to the subplot
    cbar = plt.colorbar(im, ax=ax, orientation='vertical', fraction=0.046, pad=0.04)
    cbar.set_label('EEG Intensity', fontsize=10)

    # Create a bounding box around the topomap and colorbar
    ax_bbox = ax.get_position()
    cbar_bbox = cbar.ax.get_position()

    # Determine the bounding box coordinates for the combined area
    x_min = min(ax_bbox.x0, cbar_bbox.x0)
    x_max = max(ax_bbox.x1, cbar_bbox.x1)
    y_min = min(ax_bbox.y0, cbar_bbox.y0)
    y_max = max(ax_bbox.y1, cbar_bbox.y1)

# %% [markdown]
# <h3 style="color:#FF6347; font-weight: bold;">Plotting EEG Topographic Maps for PTSD and Healthy Control :- </h3>
#
# - We define two conditions: "Healthy control" and "Posttraumatic stress disorder."
# - The `visualize` function is used to visualize the EEG data for these two conditions using the `coolwarm` colormap.
# - The plots for these two conditions will be displayed for comparison.

# %%
def visualize(dataset, channels, bands, conditions, cmap='viridis_r'):
    
    """
    Create topographical plots for all combinations of bands and conditions with boxes, column titles, and row labels.

    Parameters:
    - dataset (DataFrame): Data containing EEG levels for each condition and band.
    - channels (DataFrame): Electrode positions.
    - bands (list): List of bands to plot.
    - conditions (list): List of conditions/disorders to plot.
    - cmap (str): Colormap for plotting (inverted by default).
    """
    
    global fig  # Make fig global so we can access it in plot_topomap_with_colorbar
    num_bands = len(bands)
    num_conditions = len(conditions)
    fig, axes = plt.subplots(num_conditions, num_bands, figsize=(3 * num_bands, 3 * num_conditions), constrained_layout=True)

    for j, band in enumerate(bands):
        # Calculate the vmin and vmax for each band across all conditions
        band_data = dataset[band].values.flatten()  # Flatten to ensure we have a single array
        vmin = np.min(band_data)
        vmax = np.max(band_data)

        for i, disorder in enumerate(conditions):
            values = dataset.loc[disorder][band].values  # Select data for specific band and condition
            ax = axes[i, j] if num_conditions > 1 else axes[j]
            plot_topomap(values, channels.to_numpy(), ax, cmap=cmap, vmin=vmin, vmax=vmax)

        # Add band names as titles for each column
        axes[0, j].set_title(band, fontsize=12, pad=10)

    # Add overarching titles for each condition row
    for i, disorder in enumerate(conditions):
        axes[i, 0].annotate(
            disorder, xy=(0, 0.5), xycoords='axes fraction',
            xytext=(-axes[i, 0].yaxis.labelpad - 15, 0),
            textcoords='offset points',
            size='large', ha='right', va='center', rotation=90
        )

    plt.show()

# Example bands and conditions to plot
bands_to_plot = ['delta', 'theta', 'alpha', 'beta', 'highbeta', 'gamma']
conditions_to_plot = ['Healthy control', 'Posttraumatic stress disorder']

# %%
mean
# Out:
#                                             delta      theta      alpha  \
# specific.disorder              channel
# Acute stress disorder          FP1      21.010092  21.449696  29.986463
# Adjustment disorder            FP1      22.409204  15.188234  27.723441
# Alcohol use disorder           FP1      19.031935  14.487469  31.710026
# Behavioral addiction disorder  FP1      18.631096  13.186498  16.906313
# Bipolar disorder               FP1      20.920267  12.899219  22.731308
# ...                                           ...        ...        ...
# Obsessive compulsitve disorder O2       11.490165   9.438324  31.925618
# Panic disorder                 O2       13.623837   8.332327  20.802839
# Posttraumatic stress disorder  O2       13.845669  10.241304  28.496422
# Schizophrenia                  O2       14.780898   9.635807  28.995409
# Social anxiety disorder        O2       15.762618  10.008300  31.698667
#
#                                              beta  highbeta     gamma
# specific.disorder              channel
# Acute stress disorder          FP1      14.860550  2.419641  2.379800
# Adjustment disorder            FP1      11.964587  2.481214  3.110645
# Alcohol use disorder           FP1      12.026554  2.016023  2.193860
# Behavioral addiction disorder  FP1       9.149485  2.067112  2.643175
# Bipolar disorder               FP1      13.258815  2.519366  3.336706
# ...                                           ...       ...       ...
# Obsessive compulsitve disorder O2       11.461414  2.151135  3.304698
# Panic disorder                 O2       12.606385  2.855598  4.539175
# Posttraumatic stress disorder  O2       14.237963  2.411561  3.706658
# Schizophrenia                  O2       14.521340  2.627968  3.868594
# Social anxiety disorder        O2       15.721296  2.463267  3.656876
#
# [228 rows x 6 columns]

# %%
visualize(mean, channels, bands=bands_to_plot, conditions=conditions_to_plot)
